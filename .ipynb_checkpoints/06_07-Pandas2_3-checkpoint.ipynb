# %% [markdown]
# # <font color=blue> Đọc dữ liệu từ file csv vào dataframe </font>

# %% [markdown]
# Dữ liệu: [MovieLens 20M Dataset](https://grouplens.org/datasets/movielens/). Để chạy được các phần code bên dưới, bạn cần download bộ dữ liệu này (file `ml-20m.zip`), giải nén, rồi đặt các file csv vào thư mục chứa notebook. Có tất cả 6 file csv, trong phần demo bên dưới chỉ dùng 2 file.
#
# Theo [file mô tả dữ liệu](http://files.grouplens.org/datasets/movielens/ml-20m-README.html):
# >This dataset (ml-20m) describes 5-star rating and free-text tagging activity from MovieLens, a movie recommendation service. It contains 20000263 ratings and 465564 tag applications across 27278 movies. These data were created by 138493 users between January 09, 1995 and March 31, 2015. This dataset was generated on October 17, 2016.
# >
# >Users were selected at random for inclusion. All selected users had rated at least 20 movies. No demographic information is included. Each user is represented by an id, and no other information is provided.

# %%
# %matplotlib inline
# Theo document:
# "This performs the necessary behind-the-scenes setup 
#  for IPython to work correctly hand in hand with matplotlib"

# %%
import numpy as np
import pandas as pd

# %%
# !dir

# %%
movies_df = pd.read_csv("movies.csv")
ratings_df = pd.read_csv("ratings.csv")

# %% [markdown]
# # <font color=blue>Xem dữ liệu ở dataframe</font>

# %% [markdown]
# ## df/s.head/tail

# %%
# Xem 10 dòng đầu tiên của movies_df (nếu không truyền vào 10 thì mặc định là 5)
movies_df.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
movies_df.tail()
# Out:
#        movieId                          title                    genres
# 27273   131254   Kein Bund für's Leben (2007)                    Comedy
# 27274   131256  Feuer, Eis & Dosenbier (2002)                    Comedy
# 27275   131258             The Pirates (2014)                 Adventure
# 27276   131260            Rentun Ruusu (2001)        (no genres listed)
# 27277   131262               Innocence (2014)  Adventure|Fantasy|Horror

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %% [markdown]
# ## df.info

# %%
# Mình hay dùng df.head() khi mình cần nhớ lại mặt mũi của df
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 3 columns):
# movieId    27278 non-null int64
# title      27278 non-null object
# genres     27278 non-null object
# dtypes: int64(1), object(2)
# memory usage: 639.4+ KB

# %% [markdown]
# Kiểu dữ liệu "object" trong Pandas là gì?

# %% [markdown]
# Đọc thử [ở đây](https://stackoverflow.com/questions/21018654/strings-in-a-dataframe-but-dtype-is-object).

# %%
# Để lấy ra phần dữ liệu (Numpy array) từ dataframe df: df.values
# Numpy array này có dtype là gì?
movies_df.values
# Out:
# array([[1, 'Toy Story (1995)',
#         'Adventure|Animation|Children|Comedy|Fantasy'],
#        [2, 'Jumanji (1995)', 'Adventure|Children|Fantasy'],
#        [3, 'Grumpier Old Men (1995)', 'Comedy|Romance'],
#        ...,
#        [131258, 'The Pirates (2014)', 'Adventure'],
#        [131260, 'Rentun Ruusu (2001)', '(no genres listed)'],
#        [131262, 'Innocence (2014)', 'Adventure|Fantasy|Horror']],
#       dtype=object)

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000263 entries, 0 to 20000262
# Data columns (total 4 columns):
# userId       int64
# movieId      int64
# rating       float64
# timestamp    int64
# dtypes: float64(1), int64(3)
# memory usage: 610.4 MB

# %% [markdown]
# Tại sao `df.info` không cho biết thông tin về giá trị thiếu (null)?

# %%
ratings_df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000263 entries, 0 to 20000262
# Data columns (total 4 columns):
# userId       20000263 non-null int64
# movieId      20000263 non-null int64
# rating       20000263 non-null float64
# timestamp    20000263 non-null int64
# dtypes: float64(1), int64(3)
# memory usage: 610.4 MB

# %%
# Nếu muốn xem chắc số dòng của movies_df thì làm sao?
len(movies_df)
# Out:
# 27278

# %%
# Nếu muốn xem chắc số dòng và số cột của movies_df thì làm sao?
movies_df.shape
# Out:
# (27278, 3)

# %%
# Nếu muốn xem chắc tên cột của movies_df thì làm sao?
movies_df.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
# Nếu muốn xem chắc tên dòng của movies_df thì làm sao?
movies_df.index
# Out:
# RangeIndex(start=0, stop=27278, step=1)

# %%
# Nếu muốn xem chắc kiểu dữ liệu của các cột của movies_df thì làm sao?
movies_df.dtypes
# Out:
# movieId     int64
# title      object
# genres     object
# dtype: object

# %% [markdown]
# # <font color=blue>Truy xuất dữ liệu ở dataframe</font>

# %% [markdown]
# ## df.iloc[...]

# %% [markdown]
# `df.iloc[r, c]`
#
# - `r` có thể là:
#     - Một chỉ số vị trí (0, 1, 2, ...)
#     - List/array/series các chỉ số vị trí
#     - Slicing theo chỉ số vị trí
#     - List/array các giá trị True/False (hiện tại thì `iloc` không chạy được với series True/False)
# - `c` tương tự như `r`
# - Dùng một chỉ số vị trí (một con số) thì kết quả sẽ bị giảm chiều
#     - Nếu hoặc `r` hoặc `c` là một chỉ số vị trí (một con số) thì kết quả là series
#     - Nếu cả `r` và `c` đều là một chỉ số vị trí (một con số) thì kết quả là một giá trị

# %%
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Lấy ra phần tử ở dòng có chỉ số vị trí 2 và cột có chỉ số vị trí 1 ở movies_df
movies_df.iloc[2, 1]
# Out:
# 'Grumpier Old Men (1995)'

# %%
# Lấy ra các phần tử ở dòng có chỉ số vị trí 2 và 4 và cột có chỉ số vị trí 1 và 2 ở movies_df
movies_df.iloc[[2, 4], [1, 2]]
# Out:
#                                 title          genres
# 2             Grumpier Old Men (1995)  Comedy|Romance
# 4  Father of the Bride Part II (1995)          Comedy

# %%
# Lấy ra các phần tử từ dòng có chỉ số vị trí 2 đến 4 và từ cột có chỉ số vị trí 1 đến 2 ở movies_df
movies_df.iloc[2:5, 1:3]
# Out:
#                                 title                genres
# 2             Grumpier Old Men (1995)        Comedy|Romance
# 3            Waiting to Exhale (1995)  Comedy|Drama|Romance
# 4  Father of the Bride Part II (1995)                Comedy

# %%
# Lấy ra dòng ở chỉ số vị trí 2 của movies_df
movies_df.iloc[2, :] # Hoặc: movies_df.iloc[2]
# Out:
# movieId                          3
# title      Grumpier Old Men (1995)
# genres              Comedy|Romance
# Name: 2, dtype: object

# %%
# Lấy ra dòng ở chỉ số vị trí 2 của movies_df và làm sao để kết quả là dataframe
movies_df.iloc[[2], :]
# Out:
#    movieId                    title          genres
# 2        3  Grumpier Old Men (1995)  Comedy|Romance

# %%
# Lấy ra cột ở chỉ số vị trí 1 của movies_df
movies_df.iloc[:, 1]
shanghai Triad (Yao a yao yao dao waipo qiao) ...
# ...                                                  ...
# 27248                      Werner - Volles Rooäää (1999)
# 27249                                  What A Man (2011)
# 27250         7 Dwarves: The Forest Is Not Enough (2006)
# 27251                                 The Fat Spy (1966)
# 27252  Die Bademeister – Weiber, saufen, Leben retten...
# 27253                         Ants in the Pants 2 (2002)
# 27254                                Manta, Manta (1991)
# 27255                  Oscar and the Lady in Pink (2009)
# 27256                      Por un puñado de besos (2014)
# 27257                               Vietnam in HD (2011)
# 27258                                  WWII IN HD (2009)
# 27259                                     Phoenix (2014)
# 27260                                   Parallels (2015)
# 27261                              Closed Curtain (2013)
# 27262                                   Gentlemen (2014)
# 27263                             A Second Chance (2014)
# 27264                     Dead Rising: Watchtower (2015)
# 27265                                     Standby (2014)
# 27266                         What Men Talk About (2010)
# 27267                          Three Quarter Moon (2011)
# 27268                           Ants in the Pants (2000)
# 27269                Werner - Gekotzt wird später (2003)
# 27270                              Brother Bear 2 (2006)
# 27271                              No More School (2000)
# 27272  Forklift Driver Klaus: The First Day on the Jo...
# 27273                       Kein Bund für's Leben (2007)
# 27274                      Feuer, Eis & Dosenbier (2002)
# 27275                                 The Pirates (2014)
# 27276                                Rentun Ruusu (2001)
# 27277                                   Innocence (2014)
#
# [27278 rows x 1 columns]

# %%
# Lấy ra các dòng của ratings_df mà có rating >= 3 và <= 4
ratings_df.iloc[(ratings_df.iloc[:, 2] >= 3).values & (ratings_df.iloc[:, 2] <= 4).values, :]
# Out:
#           userId  movieId  rating   timestamp
# 0              1        2     3.5  1112486027
# 1              1       29     3.5  1112484676
# 2              1       32     3.5  1112484819
# 3              1       47     3.5  1112484727
# 4              1       50     3.5  1112484580
# 5              1      112     3.5  1094785740
# 6              1      151     4.0  1094785734
# 7              1      223     4.0  1112485573
# 8              1      253     4.0  1112484940
# 9              1      260     4.0  1112484826
# 10             1      293     4.0  1112484703
# 11             1      296     4.0  1112484767
# 12             1      318     4.0  1112484798
# 13             1      337     3.5  1094785709
# 14             1      367     3.5  1112485980
# 15             1      541     4.0  1112484603
# 16             1      589     3.5  1112485557
# 17             1      593     3.5  1112484661
# 18             1      653     3.0  1094785691
# 19             1      919     3.5  1094785621
# 20             1      924     3.5  1094785598
# 21             1     1009     3.5  1112486013
# 22             1     1036     4.0  1112485480
# 23             1     1079     4.0  1094785665
# 24             1     1080     3.5  1112485375
# 25             1     1089     3.5  1112484669
# 26             1     1090     4.0  1112485453
# 27             1     1097     4.0  1112485701
# 28             1     1136     3.5  1112484609
# 29             1     1193     3.5  1112484690
# ...          ...      ...     ...         ...
# 20000191  138493    27839     4.0  1255811481
# 20000194  138493    31193     3.5  1256750381
# 20000199  138493    33493     4.0  1258390489
# 20000200  138493    33794     4.0  1260209811
# 20000201  138493    33830     3.0  1256750671
# 20000206  138493    37729     3.5  1255810691
# 20000210  138493    39435     4.0  1256750297
# 20000214  138493    41285     4.0  1255806265
# 20000216  138493    44022     4.0  1260209449
# 20000220  138493    45668     3.5  1255810930
# 20000221  138493    45722     3.5  1255810652
# 20000222  138493    46578     4.0  1255817873
# 20000227  138493    48304     3.5  1255817394
# 20000231  138493    49651     4.0  1255817985
# 20000232  138493    50601     3.5  1258390414
# 20000233  138493    50872     3.5  1256750388
# 20000234  138493    51086     3.5  1255810566
# 20000237  138493    52579     4.0  1255856957
# 20000238  138493    52975     4.0  1256680293
# 20000239  138493    53123     4.0  1255816320
# 20000240  138493    53125     3.0  1255810649
# 20000241  138493    53322     4.0  1255812146
# 20000242  138493    53464     4.0  1260209920
# 20000246  138493    56757     3.0  1255810698
# 20000247  138493    56801     3.0  1255809988
# 20000249  138493    59315     4.0  1255818138
# 20000250  138493    59725     3.0  1255818078
# 20000252  138493    60069     4.0  1258134687
# 20000254  138493    61160     4.0  1258390537
# 20000260  138493    69644     3.0  1260209457
#
# [12053275 rows x 4 columns]

# %% [markdown]
# ## df.loc[...]

# %% [markdown]
# `df.loc[r, c]`

# %% [markdown]
# - `r` có thể là:
#     - Một tên
#     - List/array/series các tên
#     - Slicing theo tên (khác với slicing theo chỉ số vị trí, slicing theo tên bao gồm cả start **và end**)
#     - List/array/series các giá trị True/False
# - `c` tương tự như `r`
# - Dùng một tên thì kết quả sẽ bị giảm chiều
#     - Nếu hoặc `r` hoặc `c` là một tên thì kết quả là series
#     - Nếu cả `r` và `c` đều là một tên thì kết quả là một giá trị

# %%
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Lấy ra phần tử ở dòng có tên 2 và cột có tên 'title' ở movies_df
movies_df.loc[2, 'title']
# Out:
# 'Grumpier Old Men (1995)'

# %%
# Lấy ra các phần tử ở dòng có tên 2 và 4 và cột có tên 'title' và 'genres' ở movies_df
movies_df.loc[[2, 4], ['title', 'genres']]
# Out:
#                                 title          genres
# 2             Grumpier Old Men (1995)  Comedy|Romance
# 4  Father of the Bride Part II (1995)          Comedy

# %%
# Lấy ra các phần tử từ dòng có tên 2 đến tên 4 và từ cột có tên 'title' đến tên 'genres' ở movies_df
movies_df.loc[2:4, 'title':'genres']
# Out:
#                                 title                genres
# 2             Grumpier Old Men (1995)        Comedy|Romance
# 3            Waiting to Exhale (1995)  Comedy|Drama|Romance
# 4  Father of the Bride Part II (1995)                Comedy

# %%
# Lấy ra dòng có tên là 2 của movies_df
movies_df.loc[2, :] # Hoặc: movies_df.loc[2]
# Out:
# movieId                          3
# title      Grumpier Old Men (1995)
# genres              Comedy|Romance
# Name: 2, dtype: object

# %%
# Lấy ra dòng có tên là 2 của movies_df và làm sao để kết quả là dataframe
movies_df.loc[[2], :]
# Out:
#    movieId                    title          genres
# 2        3  Grumpier Old Men (1995)  Comedy|Romance

# %%
# Lấy ra cột có tên là 'title' của movies_df
movies_df.loc[:, 'title']
# Out:
# 0                                         Toy Story (1995)
# 1                                           Jumanji (1995)
# 2                                  Grumpier Old Men (1995)
# 3                                 Waiting to Exhale (1995)
# 4                       Father of the Bride Part II (1995)
# 5                                              Heat (1995)
shanghai Triad (Yao a yao yao dao waipo qiao) ...
# ...                                                  ...
# 27248                      Werner - Volles Rooäää (1999)
# 27249                                  What A Man (2011)
# 27250         7 Dwarves: The Forest Is Not Enough (2006)
# 27251                                 The Fat Spy (1966)
# 27252  Die Bademeister – Weiber, saufen, Leben retten...
# 27253                         Ants in the Pants 2 (2002)
# 27254                                Manta, Manta (1991)
# 27255                  Oscar and the Lady in Pink (2009)
# 27256                      Por un puñado de besos (2014)
# 27257                               Vietnam in HD (2011)
# 27258                                  WWII IN HD (2009)
# 27259                                     Phoenix (2014)
# 27260                                   Parallels (2015)
# 27261                              Closed Curtain (2013)
# 27262                                   Gentlemen (2014)
# 27263                             A Second Chance (2014)
# 27264                     Dead Rising: Watchtower (2015)
# 27265                                     Standby (2014)
# 27266                         What Men Talk About (2010)
# 27267                          Three Quarter Moon (2011)
# 27268                           Ants in the Pants (2000)
# 27269                Werner - Gekotzt wird später (2003)
# 27270                              Brother Bear 2 (2006)
# 27271                              No More School (2000)
# 27272  Forklift Driver Klaus: The First Day on the Jo...
# 27273                       Kein Bund für's Leben (2007)
# 27274                      Feuer, Eis & Dosenbier (2002)
# 27275                                 The Pirates (2014)
# 27276                                Rentun Ruusu (2001)
# 27277                                   Innocence (2014)
#
# [27278 rows x 1 columns]

# %%
# Lấy ra các dòng của ratings_df mà có rating >= 3 và <= 4
ratings_df.loc[(ratings_df.loc[:, 'rating'] >= 3) & (ratings_df.loc[:, 'rating'] <= 4), :]
# Out:
#           userId  movieId  rating   timestamp
# 0              1        2     3.5  1112486027
# 1              1       29     3.5  1112484676
# 2              1       32     3.5  1112484819
# 3              1       47     3.5  1112484727
# 4              1       50     3.5  1112484580
# 5              1      112     3.5  1094785740
# 6              1      151     4.0  1094785734
# 7              1      223     4.0  1112485573
# 8              1      253     4.0  1112484940
# 9              1      260     4.0  1112484826
# 10             1      293     4.0  1112484703
# 11             1      296     4.0  1112484767
# 12             1      318     4.0  1112484798
# 13             1      337     3.5  1094785709
# 14             1      367     3.5  1112485980
# 15             1      541     4.0  1112484603
# 16             1      589     3.5  1112485557
# 17             1      593     3.5  1112484661
# 18             1      653     3.0  1094785691
# 19             1      919     3.5  1094785621
# 20             1      924     3.5  1094785598
# 21             1     1009     3.5  1112486013
# 22             1     1036     4.0  1112485480
# 23             1     1079     4.0  1094785665
# 24             1     1080     3.5  1112485375
# 25             1     1089     3.5  1112484669
# 26             1     1090     4.0  1112485453
# 27             1     1097     4.0  1112485701
# 28             1     1136     3.5  1112484609
# 29             1     1193     3.5  1112484690
# ...          ...      ...     ...         ...
# 20000191  138493    27839     4.0  1255811481
# 20000194  138493    31193     3.5  1256750381
# 20000199  138493    33493     4.0  1258390489
# 20000200  138493    33794     4.0  1260209811
# 20000201  138493    33830     3.0  1256750671
# 20000206  138493    37729     3.5  1255810691
# 20000210  138493    39435     4.0  1256750297
# 20000214  138493    41285     4.0  1255806265
# 20000216  138493    44022     4.0  1260209449
# 20000220  138493    45668     3.5  1255810930
# 20000221  138493    45722     3.5  1255810652
# 20000222  138493    46578     4.0  1255817873
# 20000227  138493    48304     3.5  1255817394
# 20000231  138493    49651     4.0  1255817985
# 20000232  138493    50601     3.5  1258390414
# 20000233  138493    50872     3.5  1256750388
# 20000234  138493    51086     3.5  1255810566
# 20000237  138493    52579     4.0  1255856957
# 20000238  138493    52975     4.0  1256680293
# 20000239  138493    53123     4.0  1255816320
# 20000240  138493    53125     3.0  1255810649
# 20000241  138493    53322     4.0  1255812146
# 20000242  138493    53464     4.0  1260209920
# 20000246  138493    56757     3.0  1255810698
# 20000247  138493    56801     3.0  1255809988
# 20000249  138493    59315     4.0  1255818138
# 20000250  138493    59725     3.0  1255818078
# 20000252  138493    60069     4.0  1258134687
# 20000254  138493    61160     4.0  1258390537
# 20000260  138493    69644     3.0  1260209457
#
# [12053275 rows x 4 columns]

# %% [markdown]
# ## df[...]

# %% [markdown]
# - `df[tên hoặc list các tên]` là shortcut của `df.loc[:, tên hoặc list các tên]`
# - `df[list/array/series các giá trị True/False]` là shortcut của `df.loc[list/array/series các giá trị True/False, :]`
# - `df[slicing]` là shortcut của `df.iloc[slicing, :]`

# %%
temp = movies_df['title']
temp.head()
# Out:
# 0                      Toy Story (1995)
# 1                        Jumanji (1995)
# 2               Grumpier Old Men (1995)
# 3              Waiting to Exhale (1995)
# 4    Father of the Bride Part II (1995)
# Name: title, dtype: object

# %%
temp = ratings_df[ratings_df['rating'] > 4]
temp.head()
# Out:
#      userId  movieId  rating   timestamp
# 30        1     1196     4.5  1112484742
# 31        1     1198     4.5  1112484624
# 131       1     4993     5.0  1112484682
# 142       1     5952     5.0  1112484619
# 158       1     7153     5.0  1112484633

# %%
temp = movies_df[2:4]
temp
# Out:
#    movieId                     title                genres
# 2        3   Grumpier Old Men (1995)        Comedy|Romance
# 3        4  Waiting to Exhale (1995)  Comedy|Drama|Romance

# %% [markdown]
# # Tóm tắt dữ liệu ở dataframe

# %% [markdown]
# ## df/s.describe

# %%
# Mặc định thì chỉ "describe" các cột có giá trị số
movies_df.describe()
# Out:
#              movieId
# count   27278.000000
# mean    59855.480570
# std     44429.314697
# min         1.000000
# 25%      6931.250000
# 50%     68068.000000
# 75%    100293.250000
# max    131262.000000

# %%
# "Describe" các cột có giá trị không phải số
movies_df.describe(include=np.object)
# Out:
#                 title genres
# count           27278  27278
# unique          27262   1342
# top     Hamlet (2000)  Drama
# freq                2   4520

# %%
# Để thấy rõ hơn về các cột có giá trị không phải số, ví dụ cột 'genres'
movies_df['genres'].value_counts()
# Out:
# Drama                                              4520
# Comedy                                             2294
# Documentary                                        1942
# Comedy|Drama                                       1264
# Drama|Romance                                      1075
# Comedy|Romance                                      757
# Comedy|Drama|Romance                                605
# Horror                                              565
# Crime|Drama                                         448
# Drama|Thriller                                      426
# Drama|War                                           399
# Horror|Thriller                                     374
# Crime|Drama|Thriller                                304
# Thriller                                            268
# (no genres listed)                                  246
# Western                                             215
# Action|Drama                                        210
# Comedy|Crime                                        187
# Action                                              178
# Comedy|Horror                                       170
# Action|Comedy                                       155
# Action|Thriller                                     146
# Horror|Sci-Fi                                       140
# Comedy|Musical                                      135
# Action|Crime|Thriller                               127
# Sci-Fi                                              122
# Children|Comedy                                     119
# Horror|Mystery|Thriller                             115
# Action|Crime|Drama                                  114
# Comedy|Musical|Romance                              113
#                                                    ...
# Drama|Horror|Mystery|Thriller|War                     1
# Action|Adventure|Comedy|Crime|Thriller|War            1
# Film-Noir|Horror|Mystery|Thriller                     1
# Action|Children|Comedy|Fantasy|Sci-Fi                 1
# Action|Comedy|Film-Noir|Musical|Sci-Fi                1
# Action|Animation|Children                             1
# Adventure|Children|War                                1
# Action|Crime|Thriller|War                             1
# Sci-Fi|Thriller|Western                               1
# Action|Comedy|Crime|Fantasy|Thriller|IMAX             1
# Action|Adventure|Comedy|Drama|Romance|Thriller        1
# Crime|Horror|Mystery|Sci-Fi|Thriller                  1
# Action|Comedy|Documentary|Drama                       1
# Drama|Mystery|Romance|Sci-Fi|Thriller                 1
# Adventure|Animation|Drama|Mystery|Sci-Fi              1
# Comedy|Fantasy|Horror|Romance                         1
# Action|Fantasy|Mystery|Sci-Fi|Thriller                1
# Comedy|Crime|Film-Noir|Mystery|Romance|Thriller       1
# Action|Children|Romance                               1
# Comedy|Mystery|Romance|Thriller                       1
# Action|Adventure|Crime|Fantasy                        1
# Action|Adventure|Fantasy|Sci-Fi|IMAX                  1
# Action|Drama|Horror|Sci-Fi                            1
# Adventure|Fantasy|Thriller|IMAX                       1
# Animation|Horror|Mystery|Thriller                     1
# Animation|Children|Drama|Musical                      1
# Comedy|Drama|Fantasy|Mystery|Sci-Fi|Thriller          1
# Adventure|Crime|Drama|Horror|Mystery                  1
# Action|Adventure|Mystery|Romance|Thriller             1
# Adventure|Crime|Documentary|Drama                     1
# Name: genres, Length: 1342, dtype: int64

# %%
# pd.set_option('display.float_format', lambda x: '%.1f' %x) # Để kết quả dễ nhìn hơn thì uncomment dòng này
ratings_df.describe()
# Out:
#              userId       movieId        rating     timestamp
# count  2.000026e+07  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00  1.100918e+09
# std    4.003863e+04  1.978948e+04  1.051989e+00  1.621694e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    3.439500e+04  9.020000e+02  3.000000e+00  9.667977e+08
# 50%    6.914100e+04  2.167000e+03  3.500000e+00  1.103556e+09
# 75%    1.036370e+05  4.770000e+03  4.000000e+00  1.225642e+09
# max    1.384930e+05  1.312620e+05  5.000000e+00  1.427784e+09

# %% [markdown]
# ## df/s.hist

# %%
# Nếu gọi .hist() từ df thì sẽ vẽ các histogram cho các cột số của df
ratings_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000255899E8A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025589A792E8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025589D07898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025589D39E48>]],
#       dtype=object)

# %% [markdown]
# Để hiểu rõ hơn về histogram, dưới đây ta sẽ xem histogram của cột `rating` trong `rating_df`.

# %%
# - Nếu tham số bins = [0, 1, 2, 3] thì câu lệnh hist sẽ tạo ra 3 bin:
#   [0, 1), [1, 2), [2, 3] (để ý bin cuối bao gồm cả 3)
# - Nếu tham số density = False (mặc định) thì chiều cao của cột là số
#   lượng phần tử thuộc về bin tương ứng
ax = ratings_df['rating'].hist(bins=np.arange(0, 5.1, 0.5), grid=False, 
                       ec="black", density=False)
ax.set_xlabel("rating")
ax.set_ylabel("num elements");

# %%
# Nếu tham số density = True thì số lượng phần tử thuộc mỗi bin sẽ
# được chuẩn hóa về tỉ lệ % (cộng hết các bin lại sẽ bằng 1, 1 nghĩa
# là 100%). Lưu ý: tỉ lệ % = diện tích cột (không phải chiều cao cột).
# Với ví dụ bên dưới, các cột có độ rộng bằng nhau nên diện tích cột
# cũng tỉ lệ với chiều cao cột; nếu các cột có độ rộng không bằng nhau
# (histogram cho phép như vậy) thì bạn sẽ cần phải lưu ý.
ax = ratings_df['rating'].hist(bins=np.arange(0, 5.1, 0.5), grid=False, 
                       ec="black", density=True)
ax.set_xlabel("rating")
ax.set_ylabel("density");

# %% [markdown]
# Thử tóm tắt điểm môn Khoa Học Dữ Liệu năm trước bằng histogram.

# %%
# Bạn lấy file "dsgrades.csv" ở thùng chứa trên moodle
df = pd.read_csv("dsgrades.csv")
df.head()
# Out:
#    STT  Điểm ĐACK\r\n(50%)  Điểm các BT\r\n(50%)  Trung bình
# 0    1                 7.5                   6.5         7.0
# 1    2                 0.0                   0.0         0.0
# 2    3                 0.0                   0.0         0.0
# 3    4                 8.5                   4.5         6.5
# 4    5                 0.0                   0.5         0.5

# %%
ax = df["Trung bình"].hist(bins=np.arange(0, 11.1, 1), grid=False, 
                       ec="black", density=False)
ax.set_xlabel("grade")
ax.set_ylabel("num students");

# %% [markdown]
# Tóm tắt dữ liệu bằng histogram giúp ta thấy dữ liệu rõ ràng hơn nhiều so với chỉ dùng mean:

# %%
df["Trung bình"].mean()
# Out:
# 5.891666666666667

# %% [markdown]
# Histogram chỉ dùng được cho dữ liệu dạng số. Với dữ liệu không phải dạng số (ví dụ: thể loại phim) thì làm sao để vẽ được biều đồ tương tự?

# %% [markdown]
# Một cách là dùng `s.value_counts()` để thống kê số lần xuất hiện của các giá trị, rồi vẽ bar chart bằng `.plot.bar()` hoặc `.plot.barh()`.

# %% [markdown]
# # <font color=blue>Xử lý dữ liệu chuỗi ở dataframe</font>

# %% [markdown]
# ## s.str.xử-lý-x

# %% [markdown]
# *Gần đây có movie gì?*

# %% [markdown]
# Các bước:
# 1. Thêm cột year vào movies_df
# 2. Từ kết quả ở bước trước, sort theo year

# %%
# 1. Thêm cột year vào movies_df
df = movies_df
df = df.assign(year=df.title.str.extract(r'\((\d{4})\)'))
movies_with_year_df = df # Lưu lại kết quả vào một tên dễ nhớ vì lúc sau sẽ cần dùng đến kết quả này nhiều lần
movies_with_year_df.head()

# Nếu bạn nhớ thì khi demo trên lớp, để thêm cột year vào df thì mình không dùng câu lệnh df.assign
# mà dùng: df['year'] = df.title.str.extract(r'\((\d{4})\)')
# Câu hỏi: df.assign(year=...) khác gì với df['year'] = ...
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %%
# Luôn luôn quan sát kết quả một cách cẩn thận
movies_with_year_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 4 columns):
# movieId    27278 non-null int64
# title      27278 non-null object
# genres     27278 non-null object
# year       27256 non-null object
# dtypes: int64(1), object(3)
# memory usage: 852.5+ KB

# %%
# Có 2 vấn đề ở cột year vừa thêm vào:
# Vấn đề 1: Cột year có kiểu dữ liệu là object (ở đây là string) chứ không phải là số
# Vấn đề 2: Cột year có giá trị thiếu!

# %%
# Vấn đề 1: Cột year có kiểu dữ liệu là object (ở đây là string) chứ không phải là số
df = movies_with_year_df
df['year'] = df.year.astype('float64') # Không chuyển qua int64 được do có NaN
                                       # Lưu ý: câu lệnh này cũng sẽ làm thay đổi kiểu dữ liệu
                                       # cột year của movies_with_year_df; đây là điều ta mong 
                                       # muốn nên không có vấn đề gì cả
movies_with_year_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 4 columns):
# movieId    27278 non-null int64
# title      27278 non-null object
# genres     27278 non-null object
# year       27256 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 852.5+ KB

# %%
# Vấn đề 2: Cột year có giá trị thiếu!
df = movies_with_year_df
df[df.year.isnull()]
# Out:
#        movieId                                             title  \
# 10593    40697                                         Babylon 5
# 15646    79607           Millions Game, The (Das Millionenspiel)
# 17341    87442  Bicycle, Spoon, Apple (Bicicleta, cullera, poma)
# 22368   107434                      Diplomatic Immunity (2009– )
# 22669   108548                      Big Bang Theory, The (2007-)
# 22679   108583                         Fawlty Towers (1975-1979)
# 23617   112406             Brazil: In the Shadow of the Stadiums
# 23824   113190                                Slaying the Badger
# 24286   115133                        Tatort: Im Schmerz geboren
# 24412   115685               National Theatre Live: Frankenstein
# 26115   125571              The Court-Martial of Jackie Robinson
# 26127   125632                                     In Our Garden
# 26180   125958                Stephen Fry In America - New World
# 26335   126438                    Two: The Story of Roman & Nyro
# 26395   126929                                     Li'l Quinquin
# 26432   127005                   A Year Along the Abandoned Road
# 26749   128612                                        Body/Cialo
# 26784   128734                                     Polskie gówno
# 26963   129651                  The Third Reich: The Rise & Fall
# 26974   129705                                        My Own Man
# 27027   129887                                       Moving Alan
# 27114   130454               Michael Laudrup - en Fodboldspiller
#
#                              genres  year
# 10593                        Sci-Fi   NaN
# 15646  Action|Drama|Sci-Fi|Thriller   NaN
# 17341                   Documentary   NaN
# 22368                        Comedy   NaN
# 22669                        Comedy   NaN
# 22679                        Comedy   NaN
# 23617                   Documentary   NaN
# 23824                   Documentary   NaN
# 24286                         Crime   NaN
# 24412                 Drama|Fantasy   NaN
# 26115            (no genres listed)   NaN
# 26127            (no genres listed)   NaN
# 26180            (no genres listed)   NaN
# 26335             Documentary|Drama   NaN
# 26395            (no genres listed)   NaN
# 26432            (no genres listed)   NaN
# 26749          Comedy|Drama|Mystery   NaN
# 26784                Comedy|Musical   NaN
# 26963            (no genres listed)   NaN
# 26974            (no genres listed)   NaN
# 27027            (no genres listed)   NaN
# 27114            (no genres listed)   NaN

# %% [markdown]
# # <font color=blue>Xử lý giá trị thiếu ở dataframe</font>

# %% [markdown]
# ## df/s.dropna

# %%
# Vấn đề 2: Cột year có giá trị thiếu!
df = movies_with_year_df
df = df.dropna() # Bỏ các dòng có giá trị thiếu (tùy ngữ cảnh mà bạn phải xem xét là có nên bỏ hay không)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27256 entries, 0 to 27277
# Data columns (total 4 columns):
# movieId    27256 non-null int64
# title      27256 non-null object
# genres     27256 non-null object
# year       27256 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.0+ MB

# %% [markdown]
# ## df/s.fillna

# %%
# Vấn đề 2: Cột year có giá trị thiếu!
df = movies_with_year_df
df = df.fillna(-1) # Một cách khác để xử lý giá trị thiếu là điền bằng một giá trị nào đó
                   # Tùy ngữ cảnh mà bạn phải xem xét là có nên dùng cách này không
                   # và nếu dùng thì điền giá trị nào
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 4 columns):
# movieId    27278 non-null int64
# title      27278 non-null object
# genres     27278 non-null object
# year       27278 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 852.5+ KB

# %% [markdown]
# Ở trên là giới thiệu 2 cách có thể để xử lý giá trị thiếu.
# Tạm thời thì ta vẫn để nguyên movies_with_year_df có giá trị thiếu, chứ chưa xử lý gì.

# %%
movies_with_year_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 4 columns):
# movieId    27278 non-null int64
# title      27278 non-null object
# genres     27278 non-null object
# year       27256 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 852.5+ KB

# %% [markdown]
# # <font color=blue>Sắp xếp dữ liệu ở dataframe</font>

# %% [markdown]
# ## df/s.sort_values

# %% [markdown]
# *Gần đây có movie gì?*

# %% [markdown]
# Các bước:
# 1. Thêm cột year vào movies_df
# 2. Từ kết quả ở bước trước, sort theo year

# %%
# 2. Từ kết quả ở bước trước, sort theo year
movies_with_year_df.sort_values('year', ascending=False)
# Out:
#        movieId                                              title  \
# 26504   127160                        In Football We Trust (2015)
# 26502   127154                        The Mask You Live In (2015)
# 26505   127162                      Most Likely to Succeed (2015)
# 26506   127164                 What Happened, Miss Simone? (2015)
# 26928   129428       The Second Best Exotic Marigold Hotel (2015)
# 27168   130842                               Power/Rangers (2015)
# 27167   130840                                      Spring (2015)
# 26720   128552          Jönssonligan - Den perfekta stöten (2015)
# 27158   130682                                        Muck (2015)
# 26516   127188                                Advantageous (2015)
# 26518   127192                                  The Bronze (2015)
# 26519   127194                                 The D Train (2015)
# 26520   127196                 The Diary of a Teenage Girl (2015)
# 26521   127198                                        Dope (2015)
# 26522   127200                                I Smile Back (2015)
# 26523   127202              Me and Earl and the Dying Girl (2015)
# 26524   127204                               The Overnight (2015)
# 26525   127206                      People, Places, Things (2015)
# 27143   130578                                  The Gunman (2015)
# 26503   127156                              Prophet's Prey (2015)
# 26501   127152  Going Clear: Scientology and the Prison of Bel...
# 26527   127210                 Songs My Brothers Taught Me (2015)
# 26500   127148                          The Hunting Ground (2015)
# 26907   129370   SpongeBob Movie: Sponge Out of Water, The (2015)
# 26487   127122                     Last Days in the Desert (2015)
# 27192   131013                                    Get Hard (2015)
# 26488   127124                   I'll See You in My Dreams (2015)
# 26489   127126                             Seoul Searching (2015)
# 26490   127128                           Mississippi Grind (2015)
# 26491   127130                            Mistress America (2015)
# ...        ...                                                ...
# 20087    98981                     Arrival of a Train, The (1896)
# 19318    96009                                   Kiss, The (1896)
# 23796   113048               Tables Turned on the Gardener (1895)
# 25546   120869       Employees Leaving the Lumière Factory (1895)
# 19085    94951             Dickson Experimental Sound Film (1894)
# 17631    88674      Edison Kinetoscopic Record of a Sneeze (1894)
# 19213    95541                            Blacksmith Scene (1893)
# 27015   129851                            Dickson Greeting (1891)
# 27027                   (no genres listed)     NaN
# 27114                   (no genres listed)     NaN
#
# [27278 rows x 4 columns]

# %% [markdown]
# ## df/s.sort_index

# %% [markdown]
# *Vẽ đồ thị thể hiện sự thay đổi số lượng movie được sản xuất qua các năm.*

# %%
# 1. Từ movies_with_year_df, đếm số lượng movie của mỗi năm
df = movies_with_year_df
s = df.year.value_counts()
# 2. Từ kết quả ở bước trước, vẽ đồ thị dạng line
s = s.sort_index() # Trước khi vẽ, cần sort index
s.plot.line()

# %% [markdown]
# Tại sao ở cuối đồ thị, số lượng movie lại giảm xuống một cách đột ngột?

# %% [markdown]
# *Vẽ đồ thị thể hiện sự thay đổi số lượng movie thuộc thể loại action được sản xuất qua các năm.*

# %%
# Tương tự như câu trên 
# nhưng làm trên movies_with_year_df được giới hạn lại là chỉ gồm các movie thuộc thể loại Action
df = movies_with_year_df
df = df[df.genres.str.contains('Action')]
df.head()
# Out:
#     movieId                    title                              genres  \
# 5         6              Heat (1995)               Action|Crime|Thriller
# 8         9      Sudden Death (1995)                              Action
# 9        10         GoldenEye (1995)           Action|Adventure|Thriller
# 14       15  Cutthroat Island (1995)            Action|Adventure|Romance
# 19       20       Money Train (1995)  Action|Comedy|Crime|Drama|Thriller
#
#       year
# 5   1995.0
# 8   1995.0
# 9   1995.0
# 14  1995.0
# 19  1995.0

# %% [markdown]
# # <font color=blue>Xử lý dữ liệu thời gian ở dataframe</font>

# %% [markdown]
# ## pd.to_datetime

# %% [markdown]
# *Vẽ đồ thị thể hiện sự thay đổi số lượng người đánh giá movies qua các năm.*

# %%
# 1. Chuyển cột timestamp trong ratings_df sang dạng date time
df = ratings_df
df = df.assign(timestamp=pd.to_datetime(df.timestamp, unit='s'))
df.head()
# Out:
#    userId  movieId  rating           timestamp
# 0       1        2     3.5 2005-04-02 23:53:47
# 1       1       29     3.5 2005-04-02 23:31:16
# 2       1       32     3.5 2005-04-02 23:33:39
# 3       1       47     3.5 2005-04-02 23:32:07
# 4       1       50     3.5 2005-04-02 23:29:40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000263 entries, 0 to 20000262
# Data columns (total 4 columns):
# userId       int64
# movieId      int64
# rating       float64
# timestamp    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2)
# memory usage: 610.4 MB

# %% [markdown]
# ## s.dt.xử-lý-x

# %%
# 1. Chuyển cột timestamp trong ratings_df sang dạng date time
df = ratings_df
df = df.assign(timestamp=pd.to_datetime(df.timestamp, unit='s'))
# 2. Từ kết quả ở bước trước, lấy thông tin về year và thêm cột year vào kết quả
df = df.assign(year=df.timestamp.dt.year)
ratings_with_year_df = df # Lưu lại kết quả vào một tên dễ nhớ vì lúc sau sẽ cần dùng đến kết quả này nhiều lần
ratings_with_year_df.head()
# Out:
#    userId  movieId  rating           timestamp  year
# 0       1        2     3.5 2005-04-02 23:53:47  2005
# 1       1       29     3.5 2005-04-02 23:31:16  2005
# 2       1       32     3.5 2005-04-02 23:33:39  2005
# 3       1       47     3.5 2005-04-02 23:32:07  2005
# 4       1       50     3.5 2005-04-02 23:29:40  2005

# %%
# 3. Từ kết quả ở bước trước, vẽ đồ thị dạng line
df = ratings_with_year_df
df.year.value_counts().sort_index().plot.line()

# %% [markdown]
# # <font color=blue>Kết hợp dữ liệu từ nhiều dataframe</font>

# %% [markdown]
# ## df.merge

# %% [markdown]
# *Cho biết mỗi movie (dùng title để biểu diễn movie) có bao nhiêu người đánh giá và điểm TB là bao nhiêu?*

# %%
# 1. Từ ratings_df, lấy thêm thông tin về title của movie ở movies_df
df = ratings_df.merge(movies_df[['movieId', 'title']], on='movieId')
df.head()
# Out:
#    userId  movieId  rating   timestamp           title
# 0       1        2     3.5  1112486027  Jumanji (1995)
# 1       5        2     3.0   851527569  Jumanji (1995)
# 2      13        2     3.0   849082742  Jumanji (1995)
# 3      29        2     3.0   835562174  Jumanji (1995)
# 4      34        2     3.0   846509384  Jumanji (1995)

# %% [markdown]
# # <font color=blue>Gom nhóm và tính toán trong mỗi nhóm</font>

# %% [markdown]
# ## df.groupby(tên-cột hoặc list-tên-cột).tính-toán-x

# %%
# 1. Từ ratings_df, lấy thêm thông tin về title của movie ở movies_df
df = ratings_df.merge(movies_df[['movieId', 'title']], on='movieId')
# 2. Từ kết quả ở bước trước, gom nhóm các dòng theo title;
#    với mỗi nhóm, tính số lượng người đánh giá và điểm TB
df = df.groupby('title')['rating'].agg(['size', 'mean'])
df.head()
# Out:
#                                                     size      mean
# title
# "Great Performances" Cats (1998)                     155  2.748387
# #chicagoGirl: The Social Network Takes on a Dic...     3  3.666667
# $ (Dollars) (1971)                                    24  2.833333
# $5 a Day (2008)                                       39  2.871795
# $9.99 (2008)                                          55  3.009091

# %% [markdown]
# # <font color=blue>Tổ chức lại dữ liệu ở DataFrame</font>

# %% [markdown]
# ## df/s.unstack (và df.stack)

# %% [markdown]
# *Với mỗi năm, movie nào là movie của năm (được nhiều người đánh giá nhất)?*

# %%
# 1. Từ ratings_with_year_df, lấy thông tin về title của movie ở movies_df
df = ratings_with_year_df.merge(movies_df[['movieId', 'title']])
# 2. Từ kết quả ở bước trước, gom nhóm theo year, title; với mỗi nhóm, tính size
s = df.groupby(['year', 'title']).size()
# 3. Từ kết quả ở bước trước, kéo các giá trị của index title lên thành các cột
df = s.unstack('title').fillna(0)
# 4. Từ kết quả ở bước trước, tính idxmax của mỗi dòng
df.idxmax(axis=1)
# Out:
# year
# 1995    Double Life of Veronique, The (Double Vie de V...
# 1996                                        Batman (1989)
# 1997                 Independence Day (a.k.a. ID4) (1996)
# 1998                                       Titanic (1997)
# 1999    Star Wars: Episode V - The Empire Strikes Back...
# 2000                               American Beauty (1999)
# 2001    Crouching Tiger, Hidden Dragon (Wo hu cang lon...
# 2002    Lord of the Rings: The Fellowship of the Ring,...
# 2003        Lord of the Rings: The Two Towers, The (2002)
# 2004    Lord of the Rings: The Return of the King, The...
# 2005        Lord of the Rings: The Two Towers, The (2002)
# 2006    Lord of the Rings: The Return of the King, The...
# 2007                                   Matrix, The (1999)
# 2008                                   Matrix, The (1999)
# 2009                              Dark Knight, The (2008)
# 2010                                        Avatar (2009)
# 2011                                     Inception (2010)
# 2012                                     Inception (2010)
# 2013                     Shawshank Redemption, The (1994)
# 2014                     Shawshank Redemption, The (1994)
# 2015                                   Matrix, The (1999)
# dtype: object
